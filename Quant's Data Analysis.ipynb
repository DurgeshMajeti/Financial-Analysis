# %%
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf

# %% [markdown]
# ### Portfolio of 10 stocks

# %% [raw]
# The 10 stocks are
# 1. Pressman Advertising Limited
# 2. Eicher Motors Limited
# 3. Bharat Electronics Limited
# 4. UPL Limited
# 5. GVK Power and Infrastructure Limited
# 6. The Fertilisers And Chemicals Travancore Limited
# 7. Gujarat Narmada Valley Fertilizers & Chemicals Limited
# 8. Zuari Global Limited
# 9. Zuari Agro Chemicals Limited
# 10. Aries Agro Limited

# %%
## list of the 10 company stocks
stock_list = ['PRESSMN.NS','EICHERMOT.NS','BEL.NS','UPL.NS','GVKPIL.NS','FACT.NS','GNFC.NS','ZUARIGLOB.NS','ZUARI.NS','ARIES.NS']

# %%
data = yf.download(stock_list, '2018-01-01','2021-01-18',interval='1d')
data_closing = data['Adj Close']
# Out:
# [*********************100%***********************]  10 of 10 completed

# %%
# Plot all the close prices
((data_closing.pct_change()+1).cumprod()).plot(figsize=(20, 10))

# Show the legend
plt.legend()

# Define the label for the title of the figure
plt.title("Returns", fontsize=16)

# Define the labels for x-axis and y-axis
plt.ylabel('Cumulative Returns', fontsize=14)
plt.xlabel('Year', fontsize=14)

# Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()
